# %% [markdown]
# ### Fazendo a leitura dos dados

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
emissoes_gases = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Data Science com Python/Curso_DataScience/dados/1-SEEG10_GERAL-BR_UF_2022.10.27-FINAL-SITE.xlsx',sheet_name = 'GEE Estados')
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %% [markdown]
# Chegou o momento de praticar! Vamos aplicar os conceitos aprendidos durante a aula a partir de algumas atividades. Solucione os problemas propostos através de códigos utilizando a base de dados disponibilizada no curso.

# %% [markdown]
# 1. Encontre os valores únicos das colunas "Nível 1 - Setor" e "Estado" para identificar as atividades econômicas presentes na base de dados e se todos os Estados do Brasil estão presentes no DataFrame.

# %%
emissoes_gases['Nível 1 - Setor'].unique()
# Out:
# array(['Processos Industriais', 'Agropecuária', 'Energia', 'Resíduos ',
#        'Mudança de Uso da Terra e Floresta'], dtype=object)

# %%
emissoes_gases['Estado'].unique()
# Out:
# array(['SP', 'BA', 'RJ', 'MG', 'SE', 'PR', nan, 'RO', 'AM', 'PA', 'TO',
#        'MA', 'PI', 'CE', 'RN', 'PB', 'PE', 'AL', 'MT', 'MS', 'GO', 'DF',
#        'ES', 'SC', 'RS', 'AC', 'AP', 'RR', 'BR'], dtype=object)

# %% [markdown]
# 2. Filtre o DataFrame somente com os dados dos Estados da região Sul do Brasil.

# %%
estados_sul = ['PR','SC','RS']
# Método .isin() é utilizado para filtrar mais de um valor da mesma coluna
emissoes_gases[emissoes_gases['Estado'].isin(estados_sul)]
# Out:
#                            Nível 1 - Setor              Nível 2  \
# 35                   Processos Industriais    Indústria Química
# 36                   Processos Industriais    Indústria Química
# 37                   Processos Industriais    Indústria Química
# 110                  Processos Industriais    Produtos Minerais
# 111                  Processos Industriais    Produtos Minerais
# ...                                    ...                  ...
# 103221  Mudança de Uso da Terra e Floresta  Resíduos Florestais
# 103222  Mudança de Uso da Terra e Floresta  Resíduos Florestais
# 103223  Mudança de Uso da Terra e Floresta  Resíduos Florestais
# 103224  Mudança de Uso da Terra e Floresta  Resíduos Florestais
# 103225  Mudança de Uso da Terra e Floresta  Resíduos Florestais
#
#                     Nível 3 Nível 4       Nível 5 Nível 6  \
# 35       Produção de Amônia     NaN           NaN     NaN
# 36       Produção de Amônia     NaN           NaN     NaN
# ...

# %%
# Verificação
emissoes_gases[emissoes_gases['Estado'].isin(estados_sul)]['Estado'].unique()
# Out:
# array(['PR', 'SC', 'RS'], dtype=object)

# %% [markdown]
# 3. Filtre o DataFrame somente com os dados de "Mudança de Uso da Terra e Floresta" que sejam do Estado do Amazonas.

# %%
# Usando o operador lógico & (e)
emissoes_gases[(emissoes_gases['Estado'] == 'AM') & (emissoes_gases['Nível 1 - Setor']=='Mudança de Uso da Terra e Floresta')]
# Out:
#                            Nível 1 - Setor                     Nível 2  \
# 81262   Mudança de Uso da Terra e Floresta  Alterações de Uso da Terra
# 81271   Mudança de Uso da Terra e Floresta  Alterações de Uso da Terra
# 81280   Mudança de Uso da Terra e Floresta  Alterações de Uso da Terra
# 81289   Mudança de Uso da Terra e Floresta  Alterações de Uso da Terra
# 81298   Mudança de Uso da Terra e Floresta  Alterações de Uso da Terra
# ...                                    ...                         ...
# 102803  Mudança de Uso da Terra e Floresta         Resíduos Florestais
# 102812  Mudança de Uso da Terra e Floresta         Resíduos Florestais
# 102821  Mudança de Uso da Terra e Floresta         Resíduos Florestais
# 102830  Mudança de Uso da Terra e Floresta         Resíduos Florestais
# 102839  Mudança de Uso da Terra e Floresta         Resíduos Florestais
#
#          Nível 3                 Nível 4       Nível 5  \
# 81262   Amazônia  fora de Área Protegida  Desmatamento
# ...

# %%
# Verificação
print(emissoes_gases[(emissoes_gases['Estado'] == 'AM') & (emissoes_gases['Nível 1 - Setor']=='Mudança de Uso da Terra e Floresta')]['Estado'].unique())
print(emissoes_gases[(emissoes_gases['Estado'] == 'AM') & (emissoes_gases['Nível 1 - Setor']=='Mudança de Uso da Terra e Floresta')]['Nível 1 - Setor'].unique())
# Out:
# ['AM']
# ['Mudança de Uso da Terra e Floresta']

# %% [markdown]
# 4. Encontre o valor máximo de emissão do ano de 2021 para os dados de "Agropecuária" no Estado do Pará.

# %%
# emissoes_gases['Emissão / Remoção / Bunker'].max()
# De emissoes_gases['Atividade Econômica'] == 'AGROPECUÁRIA'
# De emissoes_gases['Estado'] == 'PA'
emissoes_gases.loc[(emissoes_gases['Nível 1 - Setor'] == 'Agropecuária') & (emissoes_gases['Estado'] == 'PA'),2021].max()
# Out:
# 36856969.7986

# %% [markdown]
# ## Conhecendo os dados

# %%
emissoes_gases.columns.get_loc(1970)
# Out:
# 11

# %%
# Índice da coluna imediatamente anterior à coluna 1970
coluna_anterior = emissoes_gases.columns[10]
coluna_anterior

# Colunas
colunas_id = list(emissoes_gases.loc[:,'Nível 1 - Setor':'Produto'].columns)
colunas_values = list(emissoes_gases.loc[:,1970:2021].columns)

emissoes_por_ano = emissoes_gases.melt(id_vars= colunas_id, value_vars= colunas_values, var_name='Ano',value_name='Emissão')
emissoes_por_ano
# Out:
#                             Nível 1 - Setor  \
# 0                     Processos Industriais
# 1                     Processos Industriais
# 2                     Processos Industriais
# 3                     Processos Industriais
# 4                     Processos Industriais
# ...                                     ...
# 5372219  Mudança de Uso da Terra e Floresta
# 5372220  Mudança de Uso da Terra e Floresta
# 5372221  Mudança de Uso da Terra e Floresta
# 5372222  Mudança de Uso da Terra e Floresta
# 5372223  Mudança de Uso da Terra e Floresta
#
#                                          Nível 2                    Nível 3  \
# 0                              Indústria Química            Produção de ABS
# 1                              Indústria Química  Produção de Ácido Adípico
# 2                              Indústria Química  Produção de Ácido Adípico
# 3                              Indústria Química  Produção de Ácido Adípico
# ...

# %% [markdown]
# 1) Faça um agrupamento de dados com base na coluna "Nível 1 - Setor" para visualizar o dicionário contendo as chaves de grupos formados e a lista de índices de cada grupo.

# %%
emissoes_por_setor = emissoes_por_ano.groupby('Nível 1 - Setor')
emissoes_por_setor.groups
# Out:
# {'Agropecuária': [1137, 1138, 1139, 1140, 1141, 1142, 1143, 1144, 1145, 1146, 1147, 1148, 1149, 1150, 1151, 1152, 1153, 1154, 1155, 1156, 1157, 1158, 1159, 1160, 1161, 1162, 1163, 1164, 1165, 1166, 1167, 1168, 1169, 1170, 1171, 1172, 1173, 1174, 1175, 1176, 1177, 1178, 1179, 1180, 1181, 1182, 1183, 1184, 1185, 1186, 1187, 1188, 1189, 1190, 1191, 1192, 1193, 1194, 1195, 1196, 1197, 1198, 1199, 1200, 1201, 1202, 1203, 1204, 1205, 1206, 1207, 1208, 1209, 1210, 1211, 1212, 1213, 1214, 1215, 1216, 1217, 1218, 1219, 1220, 1221, 1222, 1223, 1224, 1225, 1226, 1227, 1228, 1229, 1230, 1231, 1232, 1233, 1234, 1235, 1236, ...], 'Energia': [24735, 24736, 24737, 24738, 24739, 24740, 24741, 24742, 24743, 24744, 24745, 24746, 24747, 24748, 24749, 24750, 24751, 24752, 24753, 24754, 24755, 24756, 24757, 24758, 24759, 24760, 24761, 24762, 24763, 24764, 24765, 24766, 24767, 24768, 24769, 24770, 24771, 24772, 24773, 24774, 24775, 24776, 24777, 24778, 24779, 24780, 24781, 24782, 24783, 24784, 24785, 24786
# ...

# %% [markdown]
# 2) Faça um agrupamento de dados com base na coluna "Nível 1 - Setor" e localize os dados do grupo "Agropecuária".

# %%
emissoes_por_setor.get_group('Agropecuária')
# Out:
#         Nível 1 - Setor           Nível 2  Nível 3  \
# 1137       Agropecuária  Cultivo de Arroz  Diretas
# 1138       Agropecuária  Cultivo de Arroz  Diretas
# 1139       Agropecuária  Cultivo de Arroz  Diretas
# 1140       Agropecuária  Cultivo de Arroz  Diretas
# 1141       Agropecuária  Cultivo de Arroz  Diretas
# ...                 ...               ...      ...
# 5293642    Agropecuária   Solos Manejados  Diretas
# 5293643    Agropecuária   Solos Manejados  Diretas
# 5293644    Agropecuária   Solos Manejados  Diretas
# 5293645    Agropecuária   Solos Manejados  Diretas
# 5293646    Agropecuária   Solos Manejados  Diretas
#
#                                           Nível 4  Nível 5  \
# 1137                                       Outros  Vegetal
# 1138                                       Outros  Vegetal
# 1139                                       Outros  Vegetal
# 1140                                       Outros  Vegetal
# ...

# %% [markdown]
# 3) Faça um agrupamento de dados com base na coluna "Nível 1 - Setor" para identificar a média de emissão de cada atividade econômica no ano de 2021.

# %%
emissoes_por_ano[emissoes_por_ano['Ano'] == 2021].groupby('Nível 1 - Setor').mean()
# Out:
# <ipython-input-34-4d184749fb6b>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   emissoes_por_ano[emissoes_por_ano['Ano'] == 2021].groupby('Nível 1 - Setor').mean()
#                                           Emissão
# Nível 1 - Setor
# Agropecuária                         53082.725943
# Energia                              75120.049185
# Mudança de Uso da Terra e Floresta  196843.405133
# Processos Industriais               787101.255789
# Resíduos                            106106.723386

# %% [markdown]
# 4) Faça um agrupamento de dados com base na coluna "Nível 1 - Setor" para identificar a soma de emissão de cada atividade econômica. Ordene os dados da maior para menor emissão.

# %%
emissoes_por_setor[['Emissão']].sum().sort_values('Emissão',ascending=False)
# Out:
#                                          Emissão
# Nível 1 - Setor
# Mudança de Uso da Terra e Floresta  2.494463e+11
# Energia                             1.244170e+11
# Agropecuária                        1.107286e+11
# Processos Industriais               2.849965e+10
# Resíduos                            1.034465e+10

# %% [markdown]
# ## Agrupamento Multi-index

# %% [markdown]
# ### Emissão por setor

# %% [markdown]
# Uma das tarefas passadas pela equipe de supervisão do órgão ambiental era de encontrar a emissão média de cada gás por ano. Conseguimos realizar essa tarefa usando o método groupby() e pivot_table() para gerar uma tabela contendo a emissão ao longo dos anos para cada um dos gases.
#
# A equipe de supervisão deseja saber agora a média de emissão para cada um dos setores econômicos da coluna "Nível 1 - Setor". Como desafio, crie uma tabela de pivô e uma visualização gráfica contendo essas informações, utilizando apenas o método pivot_table para a construção da tabela, sem utilizar o método groupby.

# %%
media_emissao_setor = emissoes_por_ano.pivot_table(index='Ano',columns='Nível 1 - Setor',values='Emissão',aggfunc='mean')
media_emissao_setor
# Out:
# Nível 1 - Setor   Agropecuária       Energia  \
# Ano
# 1970              46246.897891  16144.173809
# 1971              48036.199926  17885.238953
# 1972              50202.891428  19293.468629
# 1973              52065.314764  22056.314835
# 1974              54319.383750  23846.090343
# 1975              59391.923086  25025.762137
# 1976              62248.257994  27196.813347
# 1977              62839.220909  27651.064663
# 1978              62523.059780  29819.997276
# 1979              64523.501296  31511.362868
# 1980              69705.387399  30959.571465
# 1981              70390.316145  29480.210658
# 1982              71384.290910  29389.824750
# 1983              71565.662720  27146.873039
# 1984              74285.323337  27045.311294
# 1985              75059.690638  28107.878784
# 1986              76963.791141  31088.515049
# 1987              79371.954399  31699.189328
# 1988              81427.436298  31803.611393
# 1989              84094.568083  32285.993152
# ...

# %%
media_emissao_setor.plot(kind='line',subplots=True,figsize=(10,10));

# %% [markdown]
# ### Hora da prática

# %% [markdown]
# 1) Faça um agrupamento de dados com as colunas "Estado" e "Nível 1 - Setor", obtendo a soma de emissão e armazenando o resultado em uma tabela.

# %%
tabela_sumarizada = emissoes_por_ano.groupby(['Estado','Nível 1 - Setor'])[['Emissão']].sum()
tabela_sumarizada
# Out:
#                                                 Emissão
# Estado Nível 1 - Setor
# AC     Agropecuária                       -3.272006e+08
#        Energia                             2.071751e+08
#        Mudança de Uso da Terra e Floresta  4.704492e+09
#        Resíduos                            2.928323e+07
# AL     Agropecuária                        1.215829e+09
# ...                                                 ...
# TO     Agropecuária                        2.789108e+09
#        Energia                             5.130379e+08
#        Mudança de Uso da Terra e Floresta  6.486598e+09
#        Processos Industriais               2.613905e+07
#        Resíduos                            6.177003e+07
#
# [133 rows x 1 columns]

# %% [markdown]
# 2) Utilizando a tabela construída na atividade 1, selecione os dados referentes à "Energia" do índice "Nível 1 - Setor".

# %%
tabela_sumarizada.xs('Energia',level=1)
# Out:
#              Emissão
# Estado
# AC      2.071751e+08
# AL      5.958697e+08
# AM      1.916462e+09
# AP      2.638059e+08
# BA      4.801368e+09
# CE      1.879584e+09
# DF      9.487860e+08
# ES      2.201326e+09
# GO      2.761709e+09
# MA      1.699005e+09
# MG      9.663844e+09
# MS      1.593967e+09
# MT      2.296983e+09
# PA      2.730706e+09
# PB      8.358578e+08
# PE      2.089593e+09
# PI      5.044902e+08
# PR      5.502734e+09
# RJ      9.151787e+09
# RN      9.473144e+08
# RO      7.246552e+08
# RR      1.672719e+08
# RS      5.901596e+09
# SC      4.328366e+09
# SE      6.627356e+08
# SP      2.214979e+10
# TO      5.130379e+08

# %% [markdown]
# 3) Utilizando a tabela construída na atividade 1, encontre a atividade econômica com valor máximo de emissão do Estado de Minas Gerais

# %%
tabela_sumarizada.xs('MG',level=0).idxmax()
# Out:
# Emissão    Agropecuária
# dtype: object

# %% [markdown]
# 4) Obtenha uma tabela contendo a atividade econômica com máxima emissão para cada Estado.

# %%
valores_max = tabela_sumarizada.groupby('Estado').max().values
tabela_sumarizada = tabela_sumarizada.groupby('Estado')[['Emissão']].idxmax()
tabela_sumarizada.insert(1,'Quantidade de emissão',valores_max)
tabela_sumarizada
# Out:
#                                          Emissão  Quantidade de emissão
# Estado
# AC      (AC, Mudança de Uso da Terra e Floresta)           4.704492e+09
# AL                            (AL, Agropecuária)           1.215829e+09
# AM                                 (AM, Energia)           1.916462e+09
# AP                                 (AP, Energia)           2.638059e+08
# BA                            (BA, Agropecuária)           7.227622e+09
# BR      (BR, Mudança de Uso da Terra e Floresta)           2.587254e+10
# CE                            (CE, Agropecuária)           2.334039e+09
# DF                                 (DF, Energia)           9.487860e+08
# ES                   (ES, Processos Industriais)           2.344011e+09
# GO                            (GO, Agropecuária)           1.156308e+10
# MA      (MA, Mudança de Uso da Terra e Floresta)           1.620688e+10
# MG                            (MG, Agropecuária)           1.557237e+10
# ...

# %% [markdown]
# 5) Obtenha uma tabela contendo o Estado com máxima emissão para cada atividade econômica.

# %%
tabela_sumarizada = emissoes_por_ano.groupby(['Nível 1 - Setor','Estado'])[['Emissão']].sum()
tabela_sumarizada.groupby('Nível 1 - Setor').idxmax()
# Out:
#                                                                      Emissão
# Nível 1 - Setor
# Agropecuária                                              (Agropecuária, MG)
# Energia                                                        (Energia, SP)
# Mudança de Uso da Terra e Floresta  (Mudança de Uso da Terra e Floresta, MT)
# Processos Industriais                            (Processos Industriais, MG)
# Resíduos                                                     (Resíduos , SP)
