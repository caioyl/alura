# %% [markdown]
# #Aula 2

# %%
idade_global = 10
def verifica_se_pode_dirigir(idade_local):
  if idade_local >= 18:
    print("Tem permissão para dirigir.")
  else:
    print("Não tem permissão para dirigir.")
verifica_se_pode_dirigir(idade_global)
# Out:
# Não tem permissão para dirigir.

# %%
def verifica_se_pode_dirigir_sem_parametros():
  idade = int(input("Digite sua idade: "))
  if idade >= 18:
    print("Tem permissão para dirigir.")
  else:
    print("Não tem permissão para dirigir.")
verifica_se_pode_dirigir_sem_parametros()
# Out:
# Digite sua idade: 10
# Não tem permissão para dirigir.

# %%
def habilitacao():
 idade = int(input('Qual sua idade? '))
 if idade >= 18:
   print('Pode tirar habilitação')
 else:
   tempo = 18 - idade
   print(f'Calma... espere {tempo} ano(s) para tirar habilitação')

habilitacao()
# Out:
# Qual sua idade? 10
# Calma... espere 8 ano(s) para tirar habilitação

# %% [markdown]
# #Aula 3

# %%
idades = [10, 30, 40, 14]
def verifica_se_pode_dirigir():
  for idade in idades:
    if idade >= 18:
      print('Tem permissão.')
    else:
      print('Não tem permissão.')
verifica_se_pode_dirigir()
# Out:
# Não tem permissão.
# Tem permissão.
# Tem permissão.
# Não tem permissão.

# %% [markdown]
# ##Boleano

# %%
permissoes = []
idades = [20, 14, 40]
def verifica_se_pode_dirigir(idades, permissoes):
  for idade_local in idades:
    if idade_local >= 18:
      permissoes.append(True)
    else:
      permissoes.append(False)
verifica_se_pode_dirigir(idades, permissoes)
permissoes
# Out:
# [True, False, True]

# %%
for permissao in permissoes:
  if permissao == True:
    print('Tem permissão para dirigir')
  else:
    print('Não tem permissão para dirigir')
# Out:
# Tem permissão para dirigir
# Não tem permissão para dirigir
# Tem permissão para dirigir

# %% [markdown]
# #Aula 4

# %%
from random import randrange
type(randrange)
randrange(0, 11, 1)
# Out:
# 10

# %%
from random import randrange, seed
seed(2)

notas_matematica = []
for notas in range(12):
  notas_matematica.append(randrange(0,11,1))
print(notas_matematica)
print(len(notas_matematica))
randrange(0,11)
# Out:
# [0, 1, 1, 5, 2, 10, 4, 4, 9, 3, 9, 0]
# 12
# 9

# %% [markdown]
# Seed fixa a ordem de acordo com uma sequência pré-definida por número

# %% [markdown]
# #

# %% [markdown]
# #Aula 5

# %%
from random import randrange, seed
notas_matematica = []
seed(3)
for c in range(0,10):
  notas_matematica.append(randrange(0,11,1))
print(notas_matematica)
print(len(notas_matematica))
# Out:
# [3, 9, 8, 2, 5, 9, 7, 10, 9, 1]
# 10

# %% [markdown]
# #Aula 6

# %%
import matplotlib.pyplot as plt

# %%
x = list(range(1,11))
y = notas_matematica
plt.plot(x,y, marker='o')
plt.title("Notas de Matemática")
plt.xlabel("Provas")
plt.ylabel("Notas")
plt.show()

# %%
# Out:
# [3, 9, 8, 2, 5, 9, 7, 10, 9, 1]

# %% [markdown]
# #Exemplo

# %%
import matplotlib.pyplot as plt

notas_matematica = ['Matemática',8,7,6,6,7,7,8,10]
notas_portugues = ['Português',9,9,9,8,5,6,8,5]
notas_geografia = ['Geografia',10,10,6,7,7,7,8,7]

notas = [notas_matematica, notas_portugues, notas_geografia]
for nota in notas:
 x = list(range(1, 9))
 y = nota[1:]
 plt.plot(x, y, marker='o')
 plt.xlabel('Provas')
 plt.ylabel('Notas')
 plt.title(nota[0])
 plt.show()
# Out:
# [8, 7, 6, 6, 7, 7, 8, 10]
# [9, 9, 9, 8, 5, 6, 8, 5]
# [10, 10, 6, 7, 7, 7, 8, 7]

# %%
def verifica_se_pode_dirigir2():
  idade_do_usuario = int(input('Digite a idade: '))
  if idade_do_usuario >= 18:
    print('Tem permissão para dirigir')
  else:
    print('Não tem permissão para dirigir')

# %%
verifica_se_pode_dirigir2()
